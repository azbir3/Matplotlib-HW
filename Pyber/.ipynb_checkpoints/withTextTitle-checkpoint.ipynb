# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# load and read csv files
city_data =pd.read_csv("data/city_data.csv")
#city_data # check loaded data
ride_data =pd.read_csv("data/ride_data.csv")
# ride_data # check loaded data

# Combine the data into a single dataset
combined_city_ride_data=pd.merge(ride_data, city_data, how="left", on="city")

# Display the data table for preview
combined_city_ride_data #.head()
# Out:
#                      city                 date   fare        ride_id  \
# 0      Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1      South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# 2      Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# 3              Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# 4              South Jack  2018-03-06 04:28:35  34.58  3908451377344
# 5            South Latoya  2018-03-11 12:26:48   9.52  1994999424437
# 6           New Paulville  2018-02-27 11:17:56  43.25   793208410091
# 7            Simpsonburgh  2018-04-26 00:43:24  35.98   111953927754
# 8         South Karenland  2018-01-08 03:28:48  35.09  7995623208694
# 9           North Jasmine  2018-03-09 06:26:29  42.81  5327642267789
# 10    New Kimberlyborough  2018-02-07 01:10:11   9.34  7992781920789
# 11            West Angela  2018-01-12 01:45:27  26.86  4820052223501
# 12             Rodneyfort  2018-03-02 18:03:20  44.26  2494064867705
# ...

# %%
summary_city_ride_data=combined_city_ride_data.drop_duplicates(["city"])
#summary_city_ride_data=comined_city_ride_data.drop('index', axis=1) #should remove the column, but it does not find a column "index" as it is not part of the original data
#summary_city_ride_data=comined_city_ride_data.hide_index #questionable command, returns with error 'DataFrame' object has no attribute 'hide_index'
summary_city_ride_data.reset_index() #.head()
# Out:
#      index                 city                 date   fare        ride_id  \
# 0        0   Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1        1   South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# 2        2   Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# 3        3           Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# 4        4           South Jack  2018-03-06 04:28:35  34.58  3908451377344
# 5        5         South Latoya  2018-03-11 12:26:48   9.52  1994999424437
# 6        6        New Paulville  2018-02-27 11:17:56  43.25   793208410091
# 7        7         Simpsonburgh  2018-04-26 00:43:24  35.98   111953927754
# 8        8      South Karenland  2018-01-08 03:28:48  35.09  7995623208694
# 9        9        North Jasmine  2018-03-09 06:26:29  42.81  5327642267789
# 10      10  New Kimberlyborough  2018-02-07 01:10:11   9.34  7992781920789
# ...

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Obtain the x and y coordinates for each of the three city types

#total_revenue_sorted=purchase_data.groupby('Gender')["Price"].sum() # example only- do not use here
x_rides=combined_city_ride_data.groupby('city')["ride_id"].count()
x_rides.head() #calc of total rides per city verified
# Out:
# city
# Amandaburgh      18
# Barajasview      22
# Barronchester    16
# Bethanyland      18
# Bradshawfurt     10
# Name: ride_id, dtype: int64

# %%
drivers=summary_city_ride_data.groupby('city')["driver_count"].sum()
drivers.head()
# Out:
# city
# Amandaburgh      12
# Barajasview      26
# Barronchester    11
# Bethanyland      22
# Bradshawfurt      7
# Name: driver_count, dtype: int64

# %%
driver_count=combined_city_ride_data.groupby('city')["driver_count"].sum()
driver_count.head()
# Out:
# city
# Amandaburgh      216
# Barajasview      572
# Barronchester    176
# Bethanyland      396
# Bradshawfurt      70
# Name: driver_count, dtype: int64

# %%
driver_mean=combined_city_ride_data.groupby('city')["driver_count"].mean()
driver_mean.head().head()
# Out:
# city
# Amandaburgh      12
# Barajasview      26
# Barronchester    11
# Bethanyland      22
# Bradshawfurt      7
# Name: driver_count, dtype: int64

# %%
total_rides=x_rides*drivers # drivers impact size of the circle
total_rides.head()
# Out:
# city
# Amandaburgh      216
# Barajasview      572
# Barronchester    176
# Bethanyland      396
# Bradshawfurt      70
# dtype: int64

# %%
y_aver_fare=combined_city_ride_data.groupby('city')["fare"].mean() 
y_aver_fare.head() #calc of average fare verified
# Out:
# city
# Amandaburgh      24.641667
# Barajasview      25.332273
# Barronchester    36.422500
# Bethanyland      32.956111
# Bradshawfurt     40.064000
# Name: fare, dtype: float64

# %%
# Build the scatter plots for each city types
#total, =plt.plot(kind="scatter", x="x_rides", y="y_aver_fare", marker="o", facecolor="red",
#                 edgecolor="black", grid=True) #total
plt.scatter(x_rides, y_aver_fare, marker="o", facecolor="red", edgecolor="black", 
            label="total")
plt.xlim(0,max(x_rides)+2)
plt.legend(loc="best")
plt.grid(True)
plt.show()

# %%
# Build the scatter plots for each city types
#total data plot
plt.scatter(x_rides, y_aver_fare, s=driver_count, marker="o", facecolor="red", 
            edgecolor="black", alpha=0.5, label="all rides")
plt.xlim(0,max(x_rides)+2)
plt.legend(loc="best")
plt.grid(True)
plt.show()

# %%
total_rides=combined_city_ride_data.groupby(['type','city'])["ride_id"].count()
total_rides.head()
# Out:
# type   city
# Rural  Bradshawfurt      10
#        Garzaport          3
#        Harringtonfort     6
#        Jessicaport        6
#        Lake Jamie         6
# Name: ride_id, dtype: int64

# %%
#build the scatter plot for  Urban population
urban_rides=combined_city_ride_data["type"].value_counts()
urban_rides #calc of total rides per city verified
# Out:
# Urban       1625
# Suburban     625
# Rural        125
# Name: type, dtype: int64

# %%
urban_ride_list=combined_city_ride_data.groupby(['type','city'])["ride_id"].count()['Urban']
urban_ride_list.head()
# Out:
# city
# Amandaburgh        18
# Barajasview        22
# Carriemouth        27
# Christopherfurt    27
# Deanville          19
# Name: ride_id, dtype: int64

# %%
#build the scatter plot for  Urban population
surban_rides=combined_city_ride_data["type"].value_counts()['Suburban']
surban_rides #calc of total rides per city verified
# Out:
# 625

# %%
suburban_ride_list=combined_city_ride_data.groupby(['type','city'])["ride_id"].count()['Suburban']
suburban_ride_list.head()
# Out:
# city
# Barronchester    16
# Bethanyland      18
# Brandonfort      19
# Colemanland      22
# Davidfurt        17
# Name: ride_id, dtype: int64

# %%
#build the scatter plot for  Urban population
rural_rides=combined_city_ride_data["type"].value_counts()['Rural']
rural_rides #calc of total rides per city verified
# Out:
# 125

# %%
rural_ride_list=combined_city_ride_data.groupby(['type','city'])["ride_id"].count()['Rural']
rural_ride_list.head()
# Out:
# city
# Bradshawfurt      10
# Garzaport          3
# Harringtonfort     6
# Jessicaport        6
# Lake Jamie         6
# Name: ride_id, dtype: int64

# %%
grp_aver_fare=combined_city_ride_data.groupby(['type','city'])["fare"].mean()
grp_aver_fare.head()
# Out:
# type   city
# Rural  Bradshawfurt      40.064000
#        Garzaport         24.123333
#        Harringtonfort    33.470000
#        Jessicaport       36.013333
#        Lake Jamie        34.358333
# Name: fare, dtype: float64

# %%
# to create a new database with type set as index for subsequent subdeviding of the data
byType_city_ride_data=combined_city_ride_data.set_index(['type'])
byType_city_ride_data.head()
# Out:
#                      city                 date   fare        ride_id  \
# type
# Urban  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# Urban  South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# Urban  Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# Urban          Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# Urban          South Jack  2018-03-06 04:28:35  34.58  3908451377344
#
#        driver_count
# type
# Urban             5
# Urban            72
# Urban            57
# Urban            34
# Urban            46

# %%
# to create a database for urban rides only
urban_city_ride_data=byType_city_ride_data.loc['Urban']
urban_city_ride_data.head()
# Out:
#                      city                 date   fare        ride_id  \
# type
# Urban  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# Urban  South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# Urban  Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# Urban          Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# Urban          South Jack  2018-03-06 04:28:35  34.58  3908451377344
#
#        driver_count
# type
# Urban             5
# Urban            72
# Urban            57
# Urban            34
# Urban            46

# %%
#to calculate average fares for urban rides
urban_aver_fare=urban_city_ride_data.groupby(['city'])["fare"].mean()
urban_aver_fare.head()
# Out:
# city
# Amandaburgh        24.641667
# Barajasview        25.332273
# Carriemouth        28.314444
# Christopherfurt    24.501852
# Deanville          25.842632
# Name: fare, dtype: float64

# %%
# to create a database for suburban rides only
suburban_city_ride_data=byType_city_ride_data.loc['Suburban']
#suburban_city_ride_data # verified
#to calculate average fares for suburban rides
suburban_aver_fare=suburban_city_ride_data.groupby(['city'])["fare"].mean()
suburban_aver_fare.head()
# Out:
# city
# Barronchester    36.422500
# Bethanyland      32.956111
# Brandonfort      35.437368
# Colemanland      30.894545
# Davidfurt        31.995882
# Name: fare, dtype: float64

# %%
# to create a database for rural rides only
rural_city_ride_data=byType_city_ride_data.loc['Rural']
#rural_city_ride_data # verified
#to calculate average fares for rural rides
rural_aver_fare=rural_city_ride_data.groupby(['city'])["fare"].mean()
rural_aver_fare #.head()
# Out:
# city
# Bradshawfurt         40.064000
# Garzaport            24.123333
# Harringtonfort       33.470000
# Jessicaport          36.013333
# Lake Jamie           34.358333
# Lake Latoyabury      26.061818
# Michaelberg          34.997500
# New Ryantown         43.278333
# Newtonview           36.745000
# North Holly          29.130000
# North Jaime          30.802500
# Penaborough          35.246000
# Randallchester       29.742000
# South Jennifer       35.264286
# South Marychester    41.870000
# South Saramouth      36.160000
# Taylorhaven          42.263333
# West Heather         33.890000
# Name: fare, dtype: float64

# %%
#to create a combined scatter chart
plt.scatter(urban_ride_list, urban_aver_fare, marker="o", facecolor="salmon", edgecolor="black", label="urban")
plt.scatter(suburban_ride_list, suburban_aver_fare, marker="o", facecolor="lightblue", edgecolor="black", label="suburban")
plt.scatter(rural_ride_list, rural_aver_fare, marker="o", facecolor="yellow", edgecolor="black", label="rural")

plt.xlim(0,max(x_rides)+2)
plt.legend(loc="best")
plt.grid(True)
plt.title("Pyber Ride Sharing Data (2016)")
plt.xlabel("Total Number of Rides (Per City)")
plt.ylabel("Average Fare($)")

plt.savefig("Pyber_ANZ.png")
plt.show()

# %%
#to create a combined scatter chart
plt.scatter(urban_ride_list, urban_aver_fare, marker="o", facecolor="tomato", 
            edgecolor="black", alpha=0.5, s=driver_mean, label="Urban")
plt.scatter(suburban_ride_list, suburban_aver_fare, marker="o", facecolor="lightblue", 
            edgecolor="black", alpha=0.5, s=drivers, label="Suburban")
plt.scatter(rural_ride_list, rural_aver_fare, marker="o", facecolor="yellow", 
            edgecolor="black", alpha=0.5, s=drivers, label="Rural")

legend=plt.legend(loc="best", title="City Types", ncol=1) # three legend lines do not imact the chart, why?
#legend._legend_box=20
#legend.set_title('CityTypes\n ')
#plt.legend(loc="best")

#plt.xlim(0,max(x_rides)+2)
plt.grid(True)
plt.title("Pyber Ride Sharing Data (2016)")
plt.xlabel("Total Number of Rides (Per City)")
plt.ylabel("Average Fare($)")

plt.savefig("Pyber_ANZ.png")
plt.show()

# %%
# Show plot
plt.show()

# %%
grp2_aver_fare=combined_city_ride_data.groupby('type')["fare"].mean() 
grp2_aver_fare
# Out:
# type
# Rural       34.623440
# Suburban    30.970128
# Urban       24.525772
# Name: fare, dtype: float64

# %% [markdown]
# ## Total Fares by City Type

# %%
total_fare=combined_city_ride_data.groupby('type')["fare"].sum() 
total_fare
# Out:
# type
# Rural        4327.93
# Suburban    19356.33
# Urban       39854.38
# Name: fare, dtype: float64

# %%
# Calculate Type Percents

labels=["Rural", "Suburban", "Urban"]
sizes=total_fare
colors=["salmon", "dodgerblue", "yellow"]
explode=(0, 0, 0.1)
# Build Pie Chart
plt.title("% of Total Fares by City Type")
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
       autopct="%1.1f%%", shadow=True, startangle=150)
#plt.axis("equal")

# Save Figure # will add once chart is fixed
plt.show()

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
total_rides=combined_city_ride_data.groupby('type')["city"].count() 
total_rides
# Out:
# type
# Rural        125
# Suburban     625
# Urban       1625
# Name: city, dtype: int64

# %%
# Calculate Ride Percents

# Build Pie Chart
labels=["Rural", "Suburban", "Urban"]
sizes=total_rides
colors=["salmon", "dodgerblue", "yellow"]
explode=(0, 0, 0.1)

plt.title("% of Total Fares by City Type")
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
       autopct="%1.1f%%", shadow=True, startangle=140)
# Save Figure
plt.show()

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
total_drivers=summary_city_ride_data.groupby('type')["driver_count"].sum() 
total_drivers
# Out:
# type
# Rural         78
# Suburban     490
# Urban       2405
# Name: driver_count, dtype: int64

# %%
# Calculate Driver Percents

# Build Pie Charts
labels=["Rural", "Suburban", "Urban"]
sizes=total_drivers
colors=["salmon", "dodgerblue", "yellow"]
explode=(0, 0, 0.1)

plt.title("% of Total Fares by City Type")
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
       autopct="%1.1f%%", shadow=True, startangle=140)

# Save Figure
plt.show()

# %%
# Show Figure
plt.show()
